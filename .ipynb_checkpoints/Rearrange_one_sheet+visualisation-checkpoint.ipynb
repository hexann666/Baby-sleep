# %%
# key_diary = '1PvDofnCSTH5MH4vdU9J0fsaTjYzthPpmp4jgUvVU1Lc'

# %%
import gspread
import pandas as pd
from oauth2client.service_account import ServiceAccountCredentials

# define scope
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# add credentials to the account
creds = ServiceAccountCredentials.from_json_keyfile_name('Babysleep-tryout-client-secret.json', scope)

# authorize the clientsheet 
client = gspread.authorize(creds)

# get the instance of the Spreadsheet
sheet = client.open('Babysleep-diaries_18.01.21-19.02.21')

# %%
# get the first sheet of the Spreadsheet
sheet_instance = sheet.get_worksheet(1)

# get the total number of columns
#print(sheet_instance.col_count)

# get the value at the specific cell
sheet_instance.cell(col=10,row=2)

# returns worksheets
print(sheet_instance.col_values(7), sep='/n')

for value in sheet_instance.col_values(7):
    print(value)
# Out:
# ['', 'Время ГВ/прикорма и длительность/наименование и количество продуктов прикорма в период ВБ1 (например: 7:00 ГВ (10 мин) \n 7:30 каша рисовая (40 гр.))', '6:55 ГВ (15 мин)\n8:00 детская рисовая каша с яблочным пюре (10гр)\n9:06 ГВ (15 мин)', '7:58 ГВ (15 мин)\n8:30 детская гречневая каша (20гр)\n9:57 ГВ (13 мин)', '5:41 ГВ (40 мин)\n8:02 ГВ (10 мин)\n9:30 детская гречневая каша (15гр)\n10:12 ГВ (17 мин)', '7:28 ГВ (13 мин)\n8:30 детская рисовая каша (20 гр), голубика (10 гр)\n9:30 ГВ (15 мин)', '7:52 ГВ (8 мин)\n8:45 геркулесовая каша «Монастырская» (20гр)\n9:52 ГВ (23 мин)', '7:06 ГВ (12 мин)\n9:03 ГВ (17 мин)', '6:40 ГВ (на подсосе в течение часа)\n8:30 «монастырский» геркулес (15гр)\n9:16 ГВ (8 мин)', '6:03 ГВ (10 мин)\n7:01 ГВ (14 мин)\n9:09 ГВ (16 мин)', '6:35 ГВ (18 мин)\n7:45 детская гречневая каша (25гр)\n8:30 груша 1/8', '7:30 ГВ (14 мин)\n9:00 пшенная каша (столовая ложка)', '7:25 ГВ (15 мин)\n8:30 детская гречневая каша (30гр)\n9:51 ГВ (8 мин)\n10:09 ГВ (10 мин)', '6:27 ГВ (30 мин)\n9:15 омлет (столовая ложка), сыр (чайная ложка)', '6:30 ГВ (полтора часа)\n9:10 геркулесовая каша (30гр)\n10:25 ГВ (4 мин)\n11:25 ГВ (11 мин)', '7:20:00 ГВ (15 мин)\n8:30 банан (30гр)\n10:11 ГВ (8 мин)\n', '7:00 ГВ (30 мин)\n8:00 1/2 яблока\n9:02 ГВ (5 мин)\n9:58 ГВ (8 мин)', '7:35 ГВ (20 мин)\n8:50 яблоко, банан, голубика (50гр)\n9:40 ГВ (10 мин)\n10:20 ГВ (22 мин)\n10:58 ГВ (11 мин)', '7:30 ГВ (20 мин)\n8:45 10 ягод голубики, детская гречневая каша (40гр)\n9:10 ГВ (8 мин)', '7:45 ГВ (10 мин)\n8:30 детская рисовая каша и проба киви\n9:54 ГВ (12 мин)\n10:48 ГВ (7 мин)', '7:30 ГВ (20 мин)
# 7:11 ГВ (19 мин)
# 8:45 2 ягоды малины, творожная запеканка (10гр), 1/8 яблока
# 9:40 ГВ (5 мин)
# 10:55 ГВ (7 мин)
# 6:07 ГВ (40 мин)
# 7:19 ГВ (5 мин)
# 8:15 10 ягод голубики, детская гречневая молочная каша
# 9:14 ГВ (11 мин)
# 6:43 ГВ (33 мин)
# 8:30 манная каша (50гр), 10 ягод голубики
# 9:30 ГВ (13 мин)
# 10:53 ГВ (3 мин)
# 7:02 ГВ (14 мин)
# 9:35 ГВ (5 мин)
#
# 7:16 ГВ (8 мин)
# 8:45 омлет (20гр) и 2 помидорки черри (проба)
# 9:45 ГВ (8 мин)
# 11:00 ГВ (10 мин)
# 6:20 ГВ (33 мин)
# 8:30 каша 5 злаков (20гр), банан (20гр)
# 9:36 ГВ (8 мин)
# 10:48 ГВ (4 мин)
# 6:48 ГВ (15 мин)
# 8:30 огурец (30гр), 1/4 яблока (кашу есть не стала)

# %% [markdown]
# Import spreadsheet as a dataframe

# %%
import gspread_dataframe as gd
df = gd.get_as_dataframe(sheet_instance,evaluate_formulas = True,skiprows = 1, has_header = True)

#how many columns and rows?
print('shape of DataFrame: ', df.shape) #with NaN values in rows
print('row count of DataFrame:\n', df.count())

# import colunm names
print(df.columns)
# Out:
# shape of DataFrame:  (967, 98)
# row count of DataFrame:
#  Дата рождения        367
# Дата                 367
# Мес.                 367
# Дн.                  367
# УТРО (проснулись)     52
#                     ...
# НОЧЬ (уже спит)       51
# ИТОГО дл-ть НС       367
# ИТОГО СНА            367
# Unnamed: 96            0
# Unnamed: 97            0
# Length: 98, dtype: int64
# Index(['Дата рождения', 'Дата ', 'Мес.', 'Дн.', 'УТРО (проснулись)',
#        'УТРО (начали день)',
#        'Время ГВ/прикорма и длительность/наименование и количество продуктов прикорма в период ВБ1 (например: 7:00 ГВ (10 мин) \n 7:30 каша рисовая (40 гр.))',
#        'Время начала УКЛ. на ДС1', 'Способ УКЛ 1', 'Сон 1 начало',
#        'Сон 1 продление?', 'Сон 1 конец',
#        'Сон 1 комментарии \n(например: 8:30-9:15/9:15-10:00 (продлевали грудью))',
#        'ВБ1', 'СОН1',
#        'Время ГВ/прикорма и длительность/наименование и количество продуктов прикорма в период ВБ2',
#        'Время начала УКЛ. на ДС2', 'Способ УКЛ 2', 'Сон 2 начало',
#        'Сон 2 продление?', 'Сон 2 конец', 'Сон 2 комментарии', 'ВБ2', 'СОН2',
#        'Время ГВ/прикорма и длительность/наименование и количество продуктов прикорма в период ВБ3',
#        'Время начала УКЛ. на ДС3', 'Способ УКЛ 3', 'Сон 3 начало',
#        'Сон 3 продление?', 'Сон 3 конец', 'Сон 3 комментарии', 'ВБ3', 'СОН3',
#        'Время ГВ/прикорма и длительность/наименование и количество продуктов прикорма в период ВБ4',
#        'Время начала УКЛ. на ДС4', 'Способ УКЛ 4', 'Сон 4 начало',
#        'Сон 4 продление?', 'Сон 4 конец', 'Сон 4 комментарии', 'ВБ4', 'СОН4',
#        'Время ГВ/ИВ/прикорма и длительность/объем смеси/наименование и количество продуктов прикорма в период ВБ5',
#        'Время начала УКЛ. на ДС5', 'Способ УКЛ 5', 'Сон 5 начало',
#        'Сон 5 продление?', 'Сон 5 конец', 'Сон 5 комментарии', 'ВБ5', 'СОН5',
#        'Время начала УКЛ. на доп. ДС', 'СОНдоп начало', 'СОНдоп конец',
#        'ВБдоп', 'СОНдоп',
#        'Время ГВ/прикорма и длительность/наименование и количество продуктов прикорма в период ВБвечер',
#        'Время начала УКЛ. на НС', 'Способ УКЛ НОЧЬ',
#        'ВРЕМЯ засыпания в НОЧЬ (закрыл глазки)',
#        'ВРЕМЯ засыпания в НОЧЬ (пережолили / отпустил грудь / вышли из комнаты и т.п.)',
#        'ВБвечер', 'ИТОГО НС',
#        'Ночные пробуждения \n(например: \n1. 22:30 (ГВ, уснул через 5 мин) \n2. 0:30 (качали, уснул через 20 мин)\n\nУТРО: 7:00 по будильнику)',
#        'Кол-во ночных проб-й', 'Кол-во ночных кормлений',
#        'Максимальный интервал между ночными кормлениями (ФОРМАТ: ЧЧ,ММ (например 3,30\n - это 3 ч 30 мин; 2,15 - это 2 ч 15 мин))',
#        'Ночные гуляния?\n(ДА - активно бодрствовал;\nДА/НЕТ - долго засыпал; больше помощи;\nНЕ ГУЛЯЛ - не бодрствовал)',
#        'Раннее утро?\n(ДА (НЕ УЛОЖИЛИ): проснулся рано, больше не уснул;\nДА (УСНУЛ ОБРАТНО): проснулся рано, но удалось уложить;\nНЕТ: проснулся в привычное время или будили)',
#        'Основная ночь \n(max длит-ть непрерывного периода НС; максимальное время между пробуждениями)\nФОРМАТ: ЧЧ,ММ (например 3,30 - то есть 3 ч 30 мин; 2,15 - то есть 2 ч 15 мин)',
#        'Оцените качество ночного сна (5-отлично; 4-хорошо; 3-средне; 2-плохо; 1-ужасно)',
#        'ПРИМЕЧАНИЕ \n(Ваши дополнительные комментарии и наблюдения за малышом (Особые ситуации (прививка, ОРВИ и т.п.)? Новые навыки?))',
#        'КОММЕНТАРИЙ \n(Комментарий/ответы на дополнительные вопросы от консультанта по сну)',
#        'УТРО (проснулись).1', 'УТРО (начали день).1', 'ВБ1.1', 'ВБ2.1',
#        'ВБ3.1', 'ВБ4.1', 'ВБ5.1', 'ВБдоп.1', 'ВБвечер.1', 'ИТОГО ВБ', 'ВБ max',
#        'ВБ min', 'СОН1.1', 'СОН2.1', 'СОН3.1', 'СОН4.1', 'СОН5.1', 'СОНдоп.1',
#        'Кол-во периодов ДС', 'ИТОГО дл-ть ДС', 'НОЧЬ (уже спит)',
#        'ИТОГО дл-ть НС', 'ИТОГО СНА', 'Unnamed: 96', 'Unnamed: 97'],
#       dtype='object')

# %%
# print one column
df[['ВРЕМЯ засыпания в НОЧЬ (пережолили / отпустил грудь / вышли из комнаты и т.п.)', 'Кол-во ночных проб-й']]
# Out:
#     ВРЕМЯ засыпания в НОЧЬ (пережолили / отпустил грудь / вышли из комнаты и т.п.)  \
# 0                                                20:10
# 1                                                20:25
# 2                                                20:35
# 3                                                20:05
# 4                                                19:50
# ..                                                 ...
# 962                                                NaN
# 963                                                NaN
# 964                                                NaN
# 965                                                NaN
# 966                                                NaN
#
#      Кол-во ночных проб-й
# 0                     4.0
# 1                     4.0
# 2                     4.0
# 3                     4.0
# 4                     3.0
# ..                    ...
# 962                   NaN
# 963                   NaN
# 964                   NaN
# 965                   NaN
# 966                   NaN
#
# [967 rows x 2 columns]

# %% [markdown]
# Визуализация:
# у одного ребенка - время первого пробуждения каждый день, количество просыпаний каждый день
# у всех детей - количество просыпаний каждый день, swarmplot

# %%
# https://stackoverflow.com/questions/8924173/how-do-i-print-bold-text-in-python
# https://www.geeksforgeeks.org/args-kwargs-python/#:~:text=The%20special%20syntax%20**kwargs,and%20any%20number%20of%20them).

def pr_bold(*argv):
    for arg in argv:
        print('\033[1m',arg,'\033[0m',sep='', end=' ')

pr_bold('Hello', 'world')
# Out:
# Hello world

# %% [markdown]
# Prepare the DataFrame with only data to be visualised:
#
# 1. select columns needed for visualisation in a separate DataFrame
# 2. check, if there are NaNs - is it normal?
# 3. delete NaNs
# 4. adjust data types: date, time, integers...

# %%
# https://www.educative.io/edpresso/how-to-delete-a-column-in-pandas
# https://datatofish.com/check-nan-pandas-dataframe/
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html

import numpy as np

df_vis = df[['Дата ', 'УТРО (проснулись)', 'ВРЕМЯ засыпания в НОЧЬ (пережолили / отпустил грудь / вышли из комнаты и т.п.)', 'Кол-во ночных проб-й']].copy()
df_vis['Date'] = df_vis['Дата ']
df_vis['First wake up time'] = df_vis['УТРО (проснулись)']
df_vis['Sleep starting time'] = df_vis['ВРЕМЯ засыпания в НОЧЬ (пережолили / отпустил грудь / вышли из комнаты и т.п.)']
df_vis['Nr of night wake ups'] = df_vis['Кол-во ночных проб-й']
df_vis.drop(columns=['Дата ', 'УТРО (проснулись)', 'ВРЕМЯ засыпания в НОЧЬ (пережолили / отпустил грудь / вышли из комнаты и т.п.)', 'Кол-во ночных проб-й'], inplace=True, axis=1)

pr_bold('Shape after creation:')
print( df_vis.shape)
pr_bold('DataFrame for visualisation:\n')
print(df_vis.head())
pr_bold('\nNaNs in Data Frame?')
print(df_vis.isnull().values.any())
pr_bold('\nNaNs are in following columns:\n')
print(df_vis.isnull().sum())

df_vis.dropna(axis=0, how='all', inplace=True, subset=['Nr of night wake ups'])
pr_bold('\nShape after NaN extraction:')
print(df_vis.shape)
pr_bold('DataFrame after NaN extraction:\n')
print(df_vis.head())
pr_bold('\nAny NaN left?\n')
print(df_vis.isnull().any())
print()
df_vis['Nr of night wake ups'] = df_vis['Nr of night wake ups'].astype(int)
df_vis.info()
# Out:
# Shape after creation: (967, 4)
# DataFrame for visualisation:
#         Date First wake up time Sleep starting time  Nr of night wake ups
# 0  18.01.21               6:50               20:10                   4.0
# 1  19.01.21               7:57               20:25                   4.0
# 2  20.01.21               8:00               20:35                   4.0
# 3  21.01.21               7:28               20:05                   4.0
# 4  22.01.21               7:52               19:50                   3.0
#
# NaNs in Data Frame? True
#
# NaNs are in following columns:
#  Date                    600
# First wake up time      915
# Sleep starting time     916
# Nr of night wake ups    918
# dtype: int64
#
# Shape after NaN extraction: (49, 4)
# DataFrame after NaN extraction:
#         Date First wake up time Sleep starting time  Nr of night wake ups
# 0  18.01.21               6:50               20:10                   4.0
# 1  19.01.21               7:57               20:25                   4.0
# 2  20.01.21               8:00               20:35                   4.0
# 3  21.01.21               7:28               20:05                   4.0
# 4  22.01.21               7:52               19:50                   3.0
#
# Any NaN left?
#  Date                    False
# First wake up time      False
# Sleep starting time     False
# Nr of night wake ups    False
# dtype: bool
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  49 non-null     object
#  1   First wake up time    49 non-null     object
#  2   Sleep starting time   49 non-null     object
#  3   Nr of night wake ups  49 non-null     int32
# dtypes: int32(1), object(3)
# memory usage: 1.7+ KB

# %%
import time

# convert time into a timestamp with hours and minutes 
df_vis['First wake up time timestamp'] = pd.to_datetime(df_vis['First wake up time'], format='%H:%M').dt.time

# convert timestamp to a number
df_vis['First wake up time to int'] = [int(t.strftime('%H%M')) for t in df_vis['First wake up time timestamp']]

print(df_vis.info()) #.iloc[:,[0,1,3]])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date                          49 non-null     object
#  1   First wake up time            49 non-null     object
#  2   Sleep starting time           49 non-null     object
#  3   Nr of night wake ups          49 non-null     int32
#  4   First wake up time timestamp  49 non-null     object
#  5   First wake up time to int     49 non-null     int64
# dtypes: int32(1), int64(1), object(4)
# memory usage: 2.5+ KB
# None

# %%
import matplotlib.pyplot as plt
import matplotlib

#df_vis.sort_values('First wake up time to int')
x = df_vis['Date']
y = df_vis['First wake up time to int']

plt.scatter(x,y, alpha=0.8)
plt.xticks(np.arange(0, len(x)+1, 7), rotation = 90)
labels = [str(t.hour) + ':' + str(t.minute) for t in df_vis['First wake up time timestamp']]
#plt.yticks(labels=labels)
plt.show()

# %%
df_vis.sort_values('First wake up time to int')

fig, ax1 = plt.subplots(1,1)

ax1.scatter(df_vis['Date'], df_vis['First wake up time to int'], color='red')
labels = [str(t.hour) + ':' + str(t.minute) for t in df_vis['First wake up time timestamp']]

ax1.set_xticks(np.arange(0, 14+1, 7))
ax1.set_xticklabels(x1, rotation=90)
#ax1.set_yticklabels(labels, minor=False, rotation=45)

#set x-axis label
ax1.set_xlabel("Date",fontsize=14)
# set y-axis label
ax1.set_ylabel("Wake up time", color="red",fontsize=14)

# twin object for two different y-axis on the sample plot
ax2=ax1.twinx()
# make a plot with different y-axis using second axis object
ax2.scatter(df_vis['Date'], df_vis['Nr of night wake ups'],color="blue",marker="o")
ax2.set_ylabel("Nr of night wake ups",color="blue",fontsize=14)
# Out:
# Text(0, 0.5, 'Nr of night wake ups')

# %%
# import data with get_all_records and formate it to a DataFrame.
# doen't work as expected, only writes 2 columns :(

# get all the records of the data
records_data = sheet_instance.get_all_records()

# view the data
print(records_data)

# convert the json to dataframe
records_df = pd.DataFrame.from_dict(records_data)

# view the top records
records_df.head()
